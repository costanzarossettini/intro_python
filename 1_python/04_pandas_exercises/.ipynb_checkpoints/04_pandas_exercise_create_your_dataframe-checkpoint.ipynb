# %% [markdown]
# # Creare un DataFrame: Pokémon
#
# Questa volta non leggerai un file: costruirai direttamente i dati in Python.

# %% [markdown]
# ### Passaggio 1 — Importa le librerie necessarie

# %% [markdown]
# ### Passaggio 2 — Crea un dizionario di dati che assomiglia a questo

# %%
raw_data = ...

pokemon = pd. ...
pokemon
# Out:
#          name   evolution   type  hp pokedex
# 0   Bulbasaur     Ivysaur  grass  45     yes
# 1  Charmander  Charmeleon   fire  39      no
# 2    Squirtle   Wartortle  water  44     yes
# 3    Caterpie     Metapod    bug  45      no

# %% [markdown]
# ### Passaggio 3 — Trasforma il dizionario in un DataFrame chiamato `pokemon`

# %% [markdown]
# ### Passaggio 4 — Riordina le colonne così: `name`, `type`, `hp`, `evolution`, `pokedex`

# %% [markdown]
# ### Passaggio 5 — Aggiungi una colonna `place` con un luogo a tua scelta per ogni Pokémon

# %% [markdown]
# ### Passaggio 6 — Mostra il tipo di dati di ogni colonna
#
# Usa l'attributo `.dtypes` senza parentesi

# %% [markdown]
# ### Bonus — Inventa una domanda e rispondi
