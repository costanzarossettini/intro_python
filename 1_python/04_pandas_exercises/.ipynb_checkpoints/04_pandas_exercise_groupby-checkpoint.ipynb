# %% [markdown]
# # Raggruppare i dati: professioni
#
# Analizzerai età e genere degli utenti in base alla professione usando `groupby`.

# %% [markdown]
# ### Passaggio 1 — Importa le librerie necessarie

# %% [markdown]
# ### Passaggio 2 — Leggi il dataset
#
# Il file si trova a questo [indirizzo](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user).
#
# > **Attenzione:** i campi sono separati dal carattere `|`, non da virgole. Usa `pd.read_csv(url, sep='|')`.

# %% [markdown]
# ### Passaggio 3 — Salva i dati nella variabile `utenti`
#
# Visualizza anche le prime righe per verificare che il separatore sia stato interpretato correttamente.

# %% [markdown]
# ### Passaggio 4 — Calcola l'età media per professione
#
# > **Suggerimento:** raggruppa per `occupation`, seleziona `age` e applica `.mean()`.

# %% [markdown]
# ### Passaggio 5 — Calcola la percentuale di uomini per professione e ordinala dalla più alta alla più bassa
#
# La colonna `gender` contiene `M` e `F`. Trasforma prima il confronto `gender == 'M'` in valori booleani: la media dei booleani (`True=1`, `False=0`) corrisponde alla proporzione.

# %% [markdown]
# ### Passaggio 6 — Calcola l'età minima e massima per ogni professione

# %% [markdown]
# ### Passaggio 7 — Calcola l'età media per ogni combinazione di professione e genere
