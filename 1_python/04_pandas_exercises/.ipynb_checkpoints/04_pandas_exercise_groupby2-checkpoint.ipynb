# %% [markdown]
# # Raggruppare i dati: consumo di bevande

# %% [markdown]
# ### Introduzione
#
# In questo esercizio userai `groupby`, che segue la logica **dividi – applica – combina**: pandas divide le righe in gruppi, applica un calcolo a ogni gruppo e riunisce i risultati.
#
#
# ### Passaggio 1 — Importa le librerie necessarie

# %% [markdown]
# ### Passaggio 2 — Leggi il dataset
#
# Importa il file CSV disponibile a questo [indirizzo](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv).
#
# > **Suggerimento:** usa `pd.read_csv(url)`. Una URL può essere passata direttamente a `read_csv`, senza scaricare prima il file.

# %% [markdown]
# ### Passaggio 3 — Salva i dati nella variabile `bevande`

# %% [markdown]
# ### Passaggio 4 — Quale continente beve in media più birra?

# %% [markdown]
# ### Passaggio 5 — Mostra le statistiche del consumo di vino per ogni continente
#
# Servono conteggio, media, deviazione standard, minimo, quartili e massimo (usa `.describe()`)

# %% [markdown]
# ### Passaggio 6 — Calcola il consumo medio per continente per tutte le colonne numeriche

# %% [markdown]
# ### Passaggio 7 — Calcola il consumo mediano per continente per tutte le colonne numeriche

# %% [markdown]
# ### Passaggio 8 — Calcola media, minimo e massimo del consumo di superalcolici
