# %% [markdown]
# # Esplorare e conoscere i dati: World Food Facts
#
# Imparerai a caricare un dataset e a ispezionarne righe, colonne, tipi e indice.

# %% [markdown]
# ### Passaggio 1 — Procurati il dataset
#
# Apri la pagina [World Food Facts su Kaggle](https://www.kaggle.com/openfoodfacts/world-food-facts/data). Potrebbe essere necessario un account Kaggle. <br>
# Scarica il file .tsv (1Gb)

# %% [markdown]
# ### Passaggio 2 — Scarica e decomprimi il dataset
#
# Individua il file TSV sul tuo computer e annotane il percorso. Un file TSV usa tabulazioni per separare le colonne.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Passaggio 3 — Leggi il TSV in un DataFrame chiamato `cibo`

# %%
# Sostituisci questo percorso con la posizione reale del file sul tuo computer.
cibo = pd.read_csv(
    'percorso/del/file/en.openfoodfacts.org.products.tsv',
    sep='\t',
    low_memory=False,
)

# %% [markdown]
# ### Passaggio 4 — Visualizza le prime cinque righe
#
# > **Da ricordare:** `.head()` mostra cinque righe per impostazione predefinita; `.head(10)` ne mostrerebbe dieci.

# %% [markdown]
# ### Passaggio 5 — Quante osservazioni (righe) contiene il dataset?

# %% [markdown]
# ### Passaggio 6 — Quante colonne contiene il dataset?

# %% [markdown]
# ### Passaggio 7 — Stampa il nome di tutte le colonne

# %% [markdown]
# ### Passaggio 8 — Come si chiama la 105ª colonna?

# %% [markdown]
# ### Passaggio 9 — Qual è il tipo dei valori nella 105ª colonna?

# %% [markdown]
# ### Passaggio 10 — Come è indicizzato il dataset?
#
# > **Suggerimento:** usa `cibo.index`. Un `RangeIndex` indica normalmente una sequenza di interi consecutivi.

# %% [markdown]
# ### Passaggio 11 — Qual è il nome del prodotto nella 19ª osservazione?
#
# Usa le posizioni, ricordando che la 19ª riga è in posizione `18`.
